# %%
import pandas as pd
import os

# %%
df = pd.read_csv('../data/radiologydata.csv')

# %%
df.head()
# Out:
#       uid article_date article_type           specialty           publisher  \
# 0    CXR1   2013-08-01           XR  pulmonary diseases  Indiana University
# 1    CXR1   2013-08-01           XR  pulmonary diseases  Indiana University
# 2   CXR10   2013-08-01           XR  pulmonary diseases  Indiana University
# 3   CXR10   2013-08-01           XR  pulmonary diseases  Indiana University
# 4  CXR100   2013-08-01           XR  pulmonary diseases  Indiana University
#
#                 comparison                       indication  \
# 0                    None.                 Positive TB test
# 1                    None.                 Positive TB test
# 2  Chest radiographs XXXX.  XXXX-year-old male, chest pain.
# 3  Chest radiographs XXXX.  XXXX-year-old male, chest pain.
# 4                    None.                              NaN
#
#                                             findings  \
# 0  The cardiac silhouette and mediastinum size ar...
# ...
